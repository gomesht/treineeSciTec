# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 

sns.set_style(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
#Carregar dados do carnaval de BH
df = pd.read_csv("Dados_Carnaval_BH_2019.csv" , sep=";", on_bad_lines='skip')

# %%
print("--- 5 Primeiras Linhas do DataFrame ---")
display(df.head())
print("\n--- 5 Últimas Linhas do DataFrame ---")
display(df.tail())
print("\n--- 5 linhas Aleatórias do DataFrame ---")
display(df.sample(5))
# Out:
# --- 5 Primeiras Linhas do DataFrame ---
#    ID    MORADOR  NUMERO_CONTROLE                   BLOCO         DT_VISITA  \
# 0   1  visitante                1            entao_brilha  02/03/2019 08:53
# 1   2  visitante                2            entao_brilha  02/03/2019 09:24
# 2   3  visitante                3     lindo_bloco_do_amor  01/03/2019 17:28
# 3   4  visitante                4  bloco_havayanas_usadas  04/03/2019 11:01
# 4   5  visitante                5  quando_come_se_lambuza  02/03/2019 09:24
#
#   TEMPO_TOTAL_ENTREV  IDADE       PAIS      ESTADO        CIDADE  \
# 0           00:05:20     22     brasil          mg  outra_cidade
# 1           00:04:12     22     brasil          mg  outra_cidade
# 2           00:05:27     23  argentina  outro_pais  outra_cidade
# 3           00:08:43     16     brasil          mg  outra_cidade
# 4           00:06:21     42     brasil          mg  outra_cidade
#
#    OUTRA_CIDADE BAIRRO_BH REGIAO_BH           REGIONAL_ORIGEM  \
# 0   divinopolis       NaN       NaN  interior_de_minas_gerais
# 1     congonhas       NaN       NaN  interior_de_minas_gerais
# 2  buenos_aires       NaN       NaN             outros_paises
# 3   divinopolis       NaN       NaN  interior_de_minas_gerais
# 4    funilandia       NaN       NaN  interior_de_minas_gerais
#
#   PRETENDERIA_VIAJAR PERNOITE_BH T_PERNOITE               HOSPEDAGEM  \
# 0        nr_nao_sabe         sim          3             casa_alugada
# 1        nr_nao_sabe         sim          4  casa_de_amigos/parentes
# 2        nr_nao_sabe         sim          4  casa_de_amigos/parentes
# 3        nr_nao_sabe         sim          3  casa_de_amigos/parentes
# 4        nr_nao_sabe         sim          5  casa_de_amigos/parentes
#
#           TRANSPORTE MOTIVO_CARNAVAL       MOTIVO_OUTRO DIAS_CARNAVAL  \
# 0               trem             nao  estudos_ou_cursos             5
# 1  onibus_rodoviario             sim        nr_nao_sabe             4
# 2              aviao             sim        nr_nao_sabe             5
# 3  onibus_rodoviario             sim        nr_nao_sabe             3
# 4  onibus_rodoviario             sim        nr_nao_sabe             4
#
#   GASTOS_PRETENDIDOS PESSOAS_GASTOS ALIMENTACAO_GASTOS TRANSPORTE_GASTOS  \
# 0        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 1        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 2        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 3        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 4        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
#
#   FANTASIAS_GASTOS COMPRAS_GASTOS INGRESSOS_GASTOS OUTROS_GASTOS  \
# 0      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 1      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 2      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 3      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 4      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
#
#   HOSPEDAGEM_GASTOS PASSEIOS_GASTOS TOTAL_GASTOS  INDIVIDUAL_GASTOS  \
# 0       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 1       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 2       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 3       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 4       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
#
#   DIARIO_GASTOS                     FONTE_CARNAVAL PARTICIPOU_ANOSANTERIORES  \
# 0   nr_nao_sabe                    amigos/parentes                       sim
# 1   nr_nao_sabe                       outros_sites                       sim
# 2   nr_nao_sabe                          instagram                       sim
# 3   nr_nao_sabe                 outros_aplicativos                       nao
# 4   nr_nao_sabe  divulgacao_em_jornais,_radio_e_tv                       sim
#
#       EVOLUCAO       MOTIVO        EXPECTATIVAS AVAL_GERAL AVAL_BANHEIROS  \
# 0     melhorou  NR_NAO_SABE             superou          6              1
# 1     melhorou  NR_NAO_SABE         indiferente          9              1
# 2     melhorou  NR_NAO_SABE             superou          6              7
# 3  NR_NAO_SABE  NR_NAO_SABE  atendeu_plenamente          8              2
# 4     melhorou  NR_NAO_SABE             superou         10              1
#
#   AVAL_SEGURANCA AVAL_PRECOS PROXIMA_EDICAO MOTIVO_NAO BLOCOS_DE_RUA  \
# 0              3           5            sim        NaN           sim
# 1             10           1            sim        NaN           sim
# 2              5           6            sim        NaN           NaN
# 3              8           5            sim        NaN           NaN
# 4              9           7            sim        NaN           NaN
#
#   EVENTOS_PRIVADOS PALCOS CIRCUITO_GASTRONOMICO CITY_TOUR VISITA_CULTURAL  \
# 0              NaN    NaN                   NaN       NaN             NaN
# 1              NaN    NaN                   NaN       NaN             NaN
# 2              NaN    NaN                   NaN       NaN             NaN
# 3              NaN    NaN                   NaN       NaN             sim
# 4              NaN    NaN                   NaN       NaN             sim
#
#   NAO_SABE PRINCIPAL_PATROCINADOR     GENERO                 ESCOLARIDADE  \
# 0      NaN                 amstel  masculino     ensino_superior_completo
# 1      NaN            nr_nao_sabe   feminino        ensino_medio_completo
# 2      NaN                   skol   feminino        ensino_medio_completo
# 3      NaN                   skol   feminino  ensino_fundamental_completo
# 4      NaN             prefeitura   feminino     ensino_superior_completo
#
#   ESTADO_CIVIL                                 FAIXA_DE_RENDA  TRANSP_A_PE  \
# 0     solteiro    entre_1_sm_e_3_sm_(rs_998,01_a_rs_2.994,00)  outra_opcao
# 1     solteiro  entre_3_sm_e_5_sm_(rs_2.994,01_a_rs_4.990,00)  outra_opcao
# 2     solteiro                                    nr_nao_sabe  outra_opcao
# 3     solteiro                                    nr_nao_sabe  outra_opcao
# 4       casado  entre_3_sm_e_5_sm_(rs_2.994,01_a_rs_4.990,00)  outra_opcao
#
#                      TRANSP_APP TRANSP_BICICLETA TRANSP_CAR_AMIGOS_PARENTES  \
# 0                   outra_opcao      outra_opcao                outra_opcao
# 1                   outra_opcao      outra_opcao                outra_opcao
# 2  aplicativos_(uber_cabify_99)      outra_opcao                outra_opcao
# 3  aplicativos_(uber_cabify_99)      outra_opcao                outra_opcao
# 4  aplicativos_(uber_cabify_99)      outra_opcao                outra_opcao
#
#    TRANSP_TAXI TRANSP_OUTROS TRANSP_VEICULO_PROPRIO TRANSP_VEICULO_ALUGADO  \
# 0  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 1  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 2  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 3  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 4  outra_opcao   outra_opcao            outra_opcao            outra_opcao
#
#   TRANSP_ONIBUS_COLETIVO    TRANSP_NS TRANSP_METRO
# 0            outra_opcao  outra_opcao  outra_opcao
# 1            outra_opcao  outra_opcao  outra_opcao
# 2            outra_opcao  outra_opcao  outra_opcao
# 3            outra_opcao  outra_opcao  outra_opcao
# 4        onibus_coletivo  outra_opcao  outra_opcao
# --- 5 Últimas Linhas do DataFrame ---
#         ID  MORADOR  NUMERO_CONTROLE       BLOCO         DT_VISITA  \
# 1128  1129  morador             1129  ordinarios  04/03/2019 21:26
# 1129  1130  morador             1130  ordinarios  05/03/2019 12:23
# 1130  1131  morador             1131  ordinarios  05/03/2019 12:30
# 1131  1132  morador             1132  ordinarios  05/03/2019 12:38
# 1132  1133  morador             1133  ordinarios  05/03/2019 12:19
#
#      TEMPO_TOTAL_ENTREV  IDADE    PAIS ESTADO          CIDADE OUTRA_CIDADE  \
# 1128           00:04:10     25  brasil     mg  belo_horizonte          NaN
# 1129           00:06:28     41  brasil     mg        contagem          NaN
# 1130           00:05:12     23  brasil     mg  belo_horizonte          NaN
# 1131           00:05:32     34  brasil     mg       nova_lima          NaN
# 1132           00:04:44     31  brasil     mg  pedro_leopoldo          NaN
#
#          BAIRRO_BH   REGIAO_BH REGIONAL_ORIGEM PRETENDERIA_VIAJAR  \
# 1128  santa_amelia    pampulha  belo_horizonte                sim
# 1129           NaN         NaN            rmbh                sim
# 1130         serra  centro-sul  belo_horizonte                sim
# 1131           NaN         NaN            rmbh                sim
# 1132           NaN         NaN            rmbh                sim
#
#       PERNOITE_BH   T_PERNOITE   HOSPEDAGEM   TRANSPORTE MOTIVO_CARNAVAL  \
# 1128  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe     nr_nao_sabe
# 1129  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe     nr_nao_sabe
# 1130  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe     nr_nao_sabe
# 1131  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe     nr_nao_sabe
# 1132  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe     nr_nao_sabe
#
#      MOTIVO_OUTRO DIAS_CARNAVAL GASTOS_PRETENDIDOS PESSOAS_GASTOS  \
# 1128  nr_nao_sabe             2                100           real
# 1129  nr_nao_sabe             3                200           real
# 1130  nr_nao_sabe             4                450           real
# 1131  nr_nao_sabe             2                400           real
# 1132  nr_nao_sabe             2                100           real
#
#      ALIMENTACAO_GASTOS TRANSPORTE_GASTOS FANTASIAS_GASTOS COMPRAS_GASTOS  \
# 1128                  1                60               10            200
# 1129                  2               180               20             20
# 1130                  1               200               20            200
# 1131                  2               160               50              0
# 1132                  1                50               30              0
#
#      INGRESSOS_GASTOS OUTROS_GASTOS HOSPEDAGEM_GASTOS PASSEIOS_GASTOS  \
# 1128                0            20                 0             NaN
# 1129                0            50                 0             NaN
# 1130                0             0                 0             NaN
# 1131                0             0                 0             NaN
# 1132                0             0                 0             NaN
#
#      TOTAL_GASTOS  INDIVIDUAL_GASTOS DIARIO_GASTOS      FONTE_CARNAVAL  \
# 1128          NaN                290           290           instagram
# 1129          NaN                270           135  outros_aplicativos
# 1130          NaN                420           420  outros_aplicativos
# 1131          NaN                210           105  outros_aplicativos
# 1132          NaN                 80            80  outros_aplicativos
#
#      PARTICIPOU_ANOSANTERIORES                 EVOLUCAO       MOTIVO  \
# 1128                       sim  nem_melhorou_nem_piorou  NR_NAO_SABE
# 1129                       nao              NR_NAO_SABE  NR_NAO_SABE
# 1130                       sim                 melhorou  NR_NAO_SABE
# 1131                       sim                 melhorou  NR_NAO_SABE
# 1132                       sim                 melhorou  NR_NAO_SABE
#
#             EXPECTATIVAS AVAL_GERAL AVAL_BANHEIROS AVAL_SEGURANCA AVAL_PRECOS  \
# 1128  atendeu_plenamente          8              3              8           1
# 1129  atendeu_plenamente          8              6              4           5
# 1130  atendeu_plenamente         10              3             10           6
# 1131  atendeu_plenamente          9              6              7           8
# 1132  atendeu_plenamente         10              8              7          10
#
#      PROXIMA_EDICAO               MOTIVO_NAO BLOCOS_DE_RUA EVENTOS_PRIVADOS  \
# 1128            sim                      NaN           NaN              NaN
# 1129            nao  conhecer_outros_lugares           NaN              NaN
# 1130            sim                      NaN           NaN              NaN
# 1131            sim                      NaN           NaN              NaN
# 1132            sim                      NaN           NaN              NaN
#
#      PALCOS CIRCUITO_GASTRONOMICO CITY_TOUR VISITA_CULTURAL NAO_SABE  \
# 1128    NaN                   NaN       NaN             NaN      NaN
# 1129    sim                   NaN       NaN             NaN      NaN
# 1130    NaN                   NaN       NaN             NaN      NaN
# 1131    NaN                   NaN       NaN             NaN      sim
# 1132    NaN                   NaN       NaN             NaN      NaN
#
#      PRINCIPAL_PATROCINADOR     GENERO              ESCOLARIDADE ESTADO_CIVIL  \
# 1128                   skol   feminino     ensino_medio_completo     solteiro
# 1129              populacao  masculino  ensino_superior_completo       casado
# 1130              populacao   feminino     ensino_medio_completo     solteiro
# 1131              populacao   feminino  ensino_superior_completo     solteiro
# 1132             prefeitura   feminino  ensino_superior_completo     solteiro
#
#                                      FAIXA_DE_RENDA  TRANSP_A_PE  \
# 1128                   acima_de_10_sm_(rs_9.980,01)  outra_opcao
# 1129  entre_5_sm_e_7_sm_(rs_4.990,01_a_rs_6.986,00)  outra_opcao
# 1130                           ate_1_sm_(rs_998,00)  outra_opcao
# 1131  entre_3_sm_e_5_sm_(rs_2.994,01_a_rs_4.990,00)  outra_opcao
# 1132    entre_1_sm_e_3_sm_(rs_998,01_a_rs_2.994,00)  outra_opcao
#
#                         TRANSP_APP TRANSP_BICICLETA  \
# 1128                   outra_opcao      outra_opcao
# 1129                   outra_opcao      outra_opcao
# 1130                   outra_opcao      outra_opcao
# 1131  aplicativos_(uber_cabify_99)      outra_opcao
# 1132                   outra_opcao      outra_opcao
#
#        TRANSP_CAR_AMIGOS_PARENTES  TRANSP_TAXI TRANSP_OUTROS  \
# 1128  carro_de_amigos_ou_parentes  outra_opcao   outra_opcao
# 1129                  outra_opcao  outra_opcao   outra_opcao
# 1130                  outra_opcao  outra_opcao   outra_opcao
# 1131                  outra_opcao  outra_opcao   outra_opcao
# 1132  carro_de_amigos_ou_parentes  outra_opcao   outra_opcao
#
#      TRANSP_VEICULO_PROPRIO TRANSP_VEICULO_ALUGADO TRANSP_ONIBUS_COLETIVO  \
# 1128            outra_opcao            outra_opcao        onibus_coletivo
# 1129            outra_opcao            outra_opcao            outra_opcao
# 1130            outra_opcao            outra_opcao        onibus_coletivo
# 1131            outra_opcao            outra_opcao            outra_opcao
# 1132            outra_opcao            outra_opcao            outra_opcao
#
#         TRANSP_NS TRANSP_METRO
# 1128  outra_opcao  outra_opcao
# 1129  outra_opcao        metro
# 1130  outra_opcao  outra_opcao
# 1131  outra_opcao  outra_opcao
# 1132  outra_opcao  outra_opcao
# --- 5 linhas Aleatórias do DataFrame ---
#         ID  MORADOR  NUMERO_CONTROLE                   BLOCO  \
# 519    520  morador              520          beico_do_wando
# 417    418  morador              418  quando_come_se_lambuza
# 840    841  morador              841          baianas_ozadas
# 352    353  morador              353            entao_brilha
# 1107  1108  morador             1108              ordinarios
#
#              DT_VISITA TEMPO_TOTAL_ENTREV  IDADE    PAIS ESTADO  \
# 519   03/03/2019 08:18           00:03:14     45  brasil     mg
# 417   02/03/2019 09:31           00:05:11     48  brasil     mg
# 840   04/03/2019 10:32           00:02:08     45  brasil     mg
# 352   02/03/2019 08:25           00:06:22     23  brasil     mg
# 1107  05/03/2019 10:40           00:04:37     40  brasil     mg
#
#               CIDADE OUTRA_CIDADE      BAIRRO_BH   REGIAO_BH REGIONAL_ORIGEM  \
# 519   belo_horizonte          NaN  salgado_filho       oeste  belo_horizonte
# 417   belo_horizonte          NaN       anchieta  centro-sul  belo_horizonte
# 840   belo_horizonte          NaN           sion  centro-sul  belo_horizonte
# 352   belo_horizonte          NaN         plalto       norte  belo_horizonte
# 1107  belo_horizonte          NaN       taquaril       leste  belo_horizonte
#
#      PRETENDERIA_VIAJAR  PERNOITE_BH   T_PERNOITE   HOSPEDAGEM   TRANSPORTE  \
# 519                 nao  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe
# 417                 sim  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe
# 840                 sim  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe
# 352                 nao  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe
# 1107                nao  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe  nr_nao_sabe
#
#      MOTIVO_CARNAVAL MOTIVO_OUTRO DIAS_CARNAVAL GASTOS_PRETENDIDOS  \
# 519      nr_nao_sabe  nr_nao_sabe             1                 50
# 417      nr_nao_sabe  nr_nao_sabe             4                100
# 840      nr_nao_sabe  nr_nao_sabe             5                800
# 352      nr_nao_sabe  nr_nao_sabe             5                100
# 1107     nr_nao_sabe  nr_nao_sabe             1                 50
#
#      PESSOAS_GASTOS ALIMENTACAO_GASTOS TRANSPORTE_GASTOS FANTASIAS_GASTOS  \
# 519            real                  1                50               40
# 417            real                  2                60               50
# 840            real                  2               500              200
# 352            real                  1               100               16
# 1107           real                  1                30               20
#
#      COMPRAS_GASTOS INGRESSOS_GASTOS OUTROS_GASTOS HOSPEDAGEM_GASTOS  \
# 519               0                0             0                 0
# 417             200                0             0                 0
# 840             100                0             0                 0
# 352              50                0             0                 0
# 1107              0                0             0                 0
#
#      PASSEIOS_GASTOS TOTAL_GASTOS  INDIVIDUAL_GASTOS DIARIO_GASTOS  \
# 519                0          NaN                 90            90
# 417              NaN          NaN                310           155
# 840              NaN          NaN                800           400
# 352              NaN          NaN                166           166
# 1107             NaN          NaN                 50            50
#
#                      FONTE_CARNAVAL PARTICIPOU_ANOSANTERIORES     EVOLUCAO  \
# 519                       instagram                       sim     melhorou
# 417                    outros_sites                       sim     melhorou
# 840              outros_aplicativos                       sim     melhorou
# 352   aplicativo_oficial_da_belotur                       sim     melhorou
# 1107                amigos/parentes                       nao  NR_NAO_SABE
#
#            MOTIVO              EXPECTATIVAS AVAL_GERAL AVAL_BANHEIROS  \
# 519   NR_NAO_SABE                   superou         10             10
# 417   NR_NAO_SABE                   superou         10              7
# 840   NR_NAO_SABE        atendeu_plenamente         10              7
# 352   NR_NAO_SABE        atendeu_plenamente         10              7
# 1107  NR_NAO_SABE  nao_satisfez_decepcionou          7              3
#
#      AVAL_SEGURANCA  AVAL_PRECOS PROXIMA_EDICAO               MOTIVO_NAO  \
# 519              10  nr_nao_sabe            sim                      NaN
# 417               6            7            sim                      NaN
# 840               8            7            sim                      NaN
# 352               9            5            sim                      NaN
# 1107              5            5            nao  conhecer_outros_lugares
#
#      BLOCOS_DE_RUA EVENTOS_PRIVADOS PALCOS CIRCUITO_GASTRONOMICO CITY_TOUR  \
# 519            NaN              NaN    NaN                   NaN       NaN
# 417            NaN              NaN    NaN                   NaN       NaN
# 840            NaN              NaN    sim                   NaN       NaN
# 352            NaN              NaN    NaN                   NaN       NaN
# 1107           NaN              NaN    sim                   NaN       NaN
#
#      VISITA_CULTURAL NAO_SABE PRINCIPAL_PATROCINADOR     GENERO  \
# 519              NaN      NaN             prefeitura   feminino
# 417              NaN      NaN             prefeitura   feminino
# 840              NaN      NaN             prefeitura  masculino
# 352              NaN      NaN                   skol  masculino
# 1107             NaN      NaN             prefeitura   feminino
#
#                               ESCOLARIDADE ESTADO_CIVIL  \
# 519   pos-graduacao/mestrado/doutorado/mba     solteiro
# 417               ensino_superior_completo       casado
# 840               ensino_superior_completo       casado
# 352               ensino_superior_completo     solteiro
# 1107                 ensino_medio_completo       casado
#
#                                      FAIXA_DE_RENDA  TRANSP_A_PE  \
# 519   entre_3_sm_e_5_sm_(rs_2.994,01_a_rs_4.990,00)  outra_opcao
# 417                    acima_de_10_sm_(rs_9.980,01)  outra_opcao
# 840   entre_5_sm_e_7_sm_(rs_4.990,01_a_rs_6.986,00)  outra_opcao
# 352     entre_1_sm_e_3_sm_(rs_998,01_a_rs_2.994,00)  outra_opcao
# 1107                           ate_1_sm_(rs_998,00)  outra_opcao
#
#                         TRANSP_APP TRANSP_BICICLETA  \
# 519   aplicativos_(uber_cabify_99)      outra_opcao
# 417   aplicativos_(uber_cabify_99)      outra_opcao
# 840   aplicativos_(uber_cabify_99)      outra_opcao
# 352                    outra_opcao      outra_opcao
# 1107                   outra_opcao      outra_opcao
#
#      TRANSP_CAR_AMIGOS_PARENTES  TRANSP_TAXI TRANSP_OUTROS  \
# 519                 outra_opcao  outra_opcao   outra_opcao
# 417                 outra_opcao  outra_opcao   outra_opcao
# 840                 outra_opcao  outra_opcao   outra_opcao
# 352                 outra_opcao  outra_opcao   outra_opcao
# 1107                outra_opcao  outra_opcao   outra_opcao
#
#      TRANSP_VEICULO_PROPRIO TRANSP_VEICULO_ALUGADO TRANSP_ONIBUS_COLETIVO  \
# 519             outra_opcao            outra_opcao            outra_opcao
# 417             outra_opcao            outra_opcao            outra_opcao
# 840             outra_opcao            outra_opcao            outra_opcao
# 352             outra_opcao            outra_opcao            outra_opcao
# 1107        veiculo_proprio            outra_opcao            outra_opcao
#
#         TRANSP_NS TRANSP_METRO
# 519   outra_opcao  outra_opcao
# 417   outra_opcao  outra_opcao
# 840   outra_opcao  outra_opcao
# 352   outra_opcao  outra_opcao
# 1107  outra_opcao  outra_opcao

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1133 non-null   int64
#  1   MORADOR                     1133 non-null   object
#  2   NUMERO_CONTROLE             1133 non-null   int64
#  3   BLOCO                       1133 non-null   object
#  4   DT_VISITA                   1133 non-null   object
#  5   TEMPO_TOTAL_ENTREV          1133 non-null   object
#  6   IDADE                       1133 non-null   int64
#  7   PAIS                        1133 non-null   object
#  8   ESTADO                      1133 non-null   object
#  9   CIDADE                      1133 non-null   object
#  10  OUTRA_CIDADE                172 non-null    object
#  11  BAIRRO_BH                   757 non-null    object
#  12  REGIAO_BH                   757 non-null    object
#  13  REGIONAL_ORIGEM             1133 non-null   object
#  14  PRETENDERIA_VIAJAR          1133 non-null   object
#  15  PERNOITE_BH                 1133 non-null   object
#  16  T_PERNOITE                  1133 non-null   object
#  17  HOSPEDAGEM                  1133 non-null   object
#  18  TRANSPORTE                  1133 non-null   object
#  19  MOTIVO_CARNAVAL             1133 non-null   object
#  20  MOTIVO_OUTRO                1133 non-null   object
#  21  DIAS_CARNAVAL               1133 non-null   object
#  22  GASTOS_PRETENDIDOS          1133 non-null   object
#  23  PESSOAS_GASTOS              1133 non-null   object
#  24  ALIMENTACAO_GASTOS          1133 non-null   object
#  25  TRANSPORTE_GASTOS           1133 non-null   object
#  26  FANTASIAS_GASTOS            1133 non-null   object
#  27  COMPRAS_GASTOS              1133 non-null   object
#  28  INGRESSOS_GASTOS            1133 non-null   object
#  29  OUTROS_GASTOS               1133 non-null   object
#  30  HOSPEDAGEM_GASTOS           1133 non-null   object
#  31  PASSEIOS_GASTOS             425 non-null    object
#  32  TOTAL_GASTOS                172 non-null    object
#  33  INDIVIDUAL_GASTOS           1133 non-null   int64
#  34  DIARIO_GASTOS               1133 non-null   object
#  35  FONTE_CARNAVAL              1133 non-null   object
#  36  PARTICIPOU_ANOSANTERIORES   1133 non-null   object
#  37  EVOLUCAO                    1133 non-null   object
#  38  MOTIVO                      1133 non-null   object
#  39  EXPECTATIVAS                1133 non-null   object
#  40  AVAL_GERAL                  1133 non-null   object
#  41  AVAL_BANHEIROS              1133 non-null   object
#  42  AVAL_SEGURANCA              1133 non-null   object
#  43  AVAL_PRECOS                 1133 non-null   object
#  44  PROXIMA_EDICAO              1133 non-null   object
#  45  MOTIVO_NAO                  45 non-null     object
#  46  BLOCOS_DE_RUA               134 non-null    object
#  47  EVENTOS_PRIVADOS            132 non-null    object
#  48  PALCOS                      180 non-null    object
#  49  CIRCUITO_GASTRONOMICO       4 non-null      object
#  50  CITY_TOUR                   6 non-null      object
#  51  VISITA_CULTURAL             13 non-null     object
#  52  NAO_SABE                    55 non-null     object
#  53  PRINCIPAL_PATROCINADOR      1133 non-null   object
#  54  GENERO                      1133 non-null   object
#  55  ESCOLARIDADE                1133 non-null   object
#  56  ESTADO_CIVIL                1133 non-null   object
#  57  FAIXA_DE_RENDA              1133 non-null   object
#  58  TRANSP_A_PE                 1133 non-null   object
#  59  TRANSP_APP                  1133 non-null   object
#  60  TRANSP_BICICLETA            1133 non-null   object
#  61  TRANSP_CAR_AMIGOS_PARENTES  1133 non-null   object
#  62  TRANSP_TAXI                 1133 non-null   object
#  63  TRANSP_OUTROS               1133 non-null   object
#  64  TRANSP_VEICULO_PROPRIO      1133 non-null   object
#  65  TRANSP_VEICULO_ALUGADO      1133 non-null   object
#  66  TRANSP_ONIBUS_COLETIVO      1133 non-null   object
#  67  TRANSP_NS                   1133 non-null   object
#  68  TRANSP_METRO                1133 non-null   object
# dtypes: int64(4), object(65)
# memory usage: 610.9+ KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1133 non-null   int64
#  1   MORADOR                     1133 non-null   object
#  2   NUMERO_CONTROLE             1133 non-null   int64
#  3   BLOCO                       1133 non-null   object
#  4   DT_VISITA                   1133 non-null   object
#  5   TEMPO_TOTAL_ENTREV          1133 non-null   object
#  6   IDADE                       1133 non-null   int64
#  7   PAIS                        1133 non-null   object
#  8   ESTADO                      1133 non-null   object
#  9   CIDADE                      1133 non-null   object
#  10  OUTRA_CIDADE                172 non-null    object
#  11  BAIRRO_BH                   757 non-null    object
#  12  REGIAO_BH                   757 non-null    object
#  13  REGIONAL_ORIGEM             1133 non-null   object
#  14  PRETENDERIA_VIAJAR          1133 non-null   object
#  15  PERNOITE_BH                 1133 non-null   object
#  16  T_PERNOITE                  1133 non-null   object
#  17  HOSPEDAGEM                  1133 non-null   object
#  18  TRANSPORTE                  1133 non-null   object
#  19  MOTIVO_CARNAVAL             1133 non-null   object
#  20  MOTIVO_OUTRO                1133 non-null   object
#  21  DIAS_CARNAVAL               1133 non-null   object
#  22  GASTOS_PRETENDIDOS          1133 non-null   object
#  23  PESSOAS_GASTOS              1133 non-null   object
#  24  ALIMENTACAO_GASTOS          1133 non-null   object
#  25  TRANSPORTE_GASTOS           1133 non-null   object
#  26  FANTASIAS_GASTOS            1133 non-null   object
#  27  COMPRAS_GASTOS              1133 non-null   object
#  28  INGRESSOS_GASTOS            1133 non-null   object
#  29  OUTROS_GASTOS               1133 non-null   object
#  30  HOSPEDAGEM_GASTOS           1133 non-null   object
#  31  PASSEIOS_GASTOS             425 non-null    object
#  32  TOTAL_GASTOS                172 non-null    object
#  33  INDIVIDUAL_GASTOS           1133 non-null   int64
#  34  DIARIO_GASTOS               1133 non-null   object
#  35  FONTE_CARNAVAL              1133 non-null   object
#  36  PARTICIPOU_ANOSANTERIORES   1133 non-null   object
#  37  EVOLUCAO                    1133 non-null   object
#  38  MOTIVO                      1133 non-null   object
#  39  EXPECTATIVAS                1133 non-null   object
#  40  AVAL_GERAL                  1133 non-null   object
#  41  AVAL_BANHEIROS              1133 non-null   object
#  42  AVAL_SEGURANCA              1133 non-null   object
#  43  AVAL_PRECOS                 1133 non-null   object
#  44  PROXIMA_EDICAO              1133 non-null   object
#  45  MOTIVO_NAO                  45 non-null     object
#  46  BLOCOS_DE_RUA               134 non-null    object
#  47  EVENTOS_PRIVADOS            132 non-null    object
#  48  PALCOS                      180 non-null    object
#  49  CIRCUITO_GASTRONOMICO       4 non-null      object
#  50  CITY_TOUR                   6 non-null      object
#  51  VISITA_CULTURAL             13 non-null     object
#  52  NAO_SABE                    55 non-null     object
#  53  PRINCIPAL_PATROCINADOR      1133 non-null   object
#  54  GENERO                      1133 non-null   object
#  55  ESCOLARIDADE                1133 non-null   object
#  56  ESTADO_CIVIL                1133 non-null   object
#  57  FAIXA_DE_RENDA              1133 non-null   object
#  58  TRANSP_A_PE                 1133 non-null   object
#  59  TRANSP_APP                  1133 non-null   object
#  60  TRANSP_BICICLETA            1133 non-null   object
#  61  TRANSP_CAR_AMIGOS_PARENTES  1133 non-null   object
#  62  TRANSP_TAXI                 1133 non-null   object
#  63  TRANSP_OUTROS               1133 non-null   object
#  64  TRANSP_VEICULO_PROPRIO      1133 non-null   object
#  65  TRANSP_VEICULO_ALUGADO      1133 non-null   object
#  66  TRANSP_ONIBUS_COLETIVO      1133 non-null   object
#  67  TRANSP_NS                   1133 non-null   object
#  68  TRANSP_METRO                1133 non-null   object
# dtypes: int64(4), object(65)
# memory usage: 3.8 MB

# %%
df.describe(include='all').T
# Out:
#                          count unique               top  freq   mean  \
# ID                      1133.0    NaN               NaN   NaN  567.0
# MORADOR                   1133      2           morador   961    NaN
# NUMERO_CONTROLE         1133.0    NaN               NaN   NaN  567.0
# BLOCO                     1133     20      entao_brilha    96    NaN
# DT_VISITA                 1133    894  02/03/2019 08:53     4    NaN
# ...                        ...    ...               ...   ...    ...
# TRANSP_VEICULO_PROPRIO    1133      2       outra_opcao   975    NaN
# TRANSP_VEICULO_ALUGADO    1133      2       outra_opcao  1129    NaN
# TRANSP_ONIBUS_COLETIVO    1133      2       outra_opcao   892    NaN
# TRANSP_NS                 1133      2       outra_opcao  1132    NaN
# TRANSP_METRO              1133      2       outra_opcao   961    NaN
#
#                                std  min    25%    50%    75%     max
# ID                      327.213233  1.0  284.0  567.0  850.0  1133.0
# MORADOR                        NaN  NaN    NaN    NaN    NaN     NaN
# NUMERO_CONTROLE         327.213233  1.0  284.0  567.0  850.0  1133.0
# BLOCO                          NaN  NaN    NaN    NaN    NaN     NaN
# DT_VISITA                      NaN  NaN    NaN    NaN    NaN     NaN
# ...                            ...  ...    ...    ...    ...     ...
# TRANSP_VEICULO_PROPRIO         NaN  NaN    NaN    NaN    NaN     NaN
# TRANSP_VEICULO_ALUGADO         NaN  NaN    NaN    NaN    NaN     NaN
# TRANSP_ONIBUS_COLETIVO         NaN  NaN    NaN    NaN    NaN     NaN
# TRANSP_NS                      NaN  NaN    NaN    NaN    NaN     NaN
# TRANSP_METRO                   NaN  NaN    NaN    NaN    NaN     NaN
#
# [69 rows x 11 columns]

# %%
df.describe().T
# Out:
#                     count        mean         std   min    25%    50%    75%  \
# ID                 1133.0  567.000000  327.213233   1.0  284.0  567.0  850.0
# NUMERO_CONTROLE    1133.0  567.000000  327.213233   1.0  284.0  567.0  850.0
# IDADE              1133.0   32.310680   11.554780  16.0   24.0   29.0   39.0
# INDIVIDUAL_GASTOS  1133.0  423.455428  534.957360   0.0  140.0  290.0  500.0
#
#                       max
# ID                 1133.0
# NUMERO_CONTROLE    1133.0
# IDADE                73.0
# INDIVIDUAL_GASTOS  5450.0

# %%
pd.set_option('display.max_columns', None)
display(df.head())
# Out:
#    ID    MORADOR  NUMERO_CONTROLE                   BLOCO         DT_VISITA  \
# 0   1  visitante                1            entao_brilha  02/03/2019 08:53
# 1   2  visitante                2            entao_brilha  02/03/2019 09:24
# 2   3  visitante                3     lindo_bloco_do_amor  01/03/2019 17:28
# 3   4  visitante                4  bloco_havayanas_usadas  04/03/2019 11:01
# 4   5  visitante                5  quando_come_se_lambuza  02/03/2019 09:24
#
#   TEMPO_TOTAL_ENTREV  IDADE       PAIS      ESTADO        CIDADE  \
# 0           00:05:20     22     brasil          mg  outra_cidade
# 1           00:04:12     22     brasil          mg  outra_cidade
# 2           00:05:27     23  argentina  outro_pais  outra_cidade
# 3           00:08:43     16     brasil          mg  outra_cidade
# 4           00:06:21     42     brasil          mg  outra_cidade
#
#    OUTRA_CIDADE BAIRRO_BH REGIAO_BH           REGIONAL_ORIGEM  \
# 0   divinopolis       NaN       NaN  interior_de_minas_gerais
# 1     congonhas       NaN       NaN  interior_de_minas_gerais
# 2  buenos_aires       NaN       NaN             outros_paises
# 3   divinopolis       NaN       NaN  interior_de_minas_gerais
# 4    funilandia       NaN       NaN  interior_de_minas_gerais
#
#   PRETENDERIA_VIAJAR PERNOITE_BH T_PERNOITE               HOSPEDAGEM  \
# 0        nr_nao_sabe         sim          3             casa_alugada
# 1        nr_nao_sabe         sim          4  casa_de_amigos/parentes
# 2        nr_nao_sabe         sim          4  casa_de_amigos/parentes
# 3        nr_nao_sabe         sim          3  casa_de_amigos/parentes
# 4        nr_nao_sabe         sim          5  casa_de_amigos/parentes
#
#           TRANSPORTE MOTIVO_CARNAVAL       MOTIVO_OUTRO DIAS_CARNAVAL  \
# 0               trem             nao  estudos_ou_cursos             5
# 1  onibus_rodoviario             sim        nr_nao_sabe             4
# 2              aviao             sim        nr_nao_sabe             5
# 3  onibus_rodoviario             sim        nr_nao_sabe             3
# 4  onibus_rodoviario             sim        nr_nao_sabe             4
#
#   GASTOS_PRETENDIDOS PESSOAS_GASTOS ALIMENTACAO_GASTOS TRANSPORTE_GASTOS  \
# 0        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 1        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 2        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 3        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
# 4        nr_nao_sabe           real        nr_nao_sabe       nr_nao_sabe
#
#   FANTASIAS_GASTOS COMPRAS_GASTOS INGRESSOS_GASTOS OUTROS_GASTOS  \
# 0      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 1      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 2      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 3      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
# 4      nr_nao_sabe    nr_nao_sabe      nr_nao_sabe   nr_nao_sabe
#
#   HOSPEDAGEM_GASTOS PASSEIOS_GASTOS TOTAL_GASTOS  INDIVIDUAL_GASTOS  \
# 0       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 1       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 2       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 3       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
# 4       nr_nao_sabe     nr_nao_sabe  nr_nao_sabe                  0
#
#   DIARIO_GASTOS                     FONTE_CARNAVAL PARTICIPOU_ANOSANTERIORES  \
# 0   nr_nao_sabe                    amigos/parentes                       sim
# 1   nr_nao_sabe                       outros_sites                       sim
# 2   nr_nao_sabe                          instagram                       sim
# 3   nr_nao_sabe                 outros_aplicativos                       nao
# 4   nr_nao_sabe  divulgacao_em_jornais,_radio_e_tv                       sim
#
#       EVOLUCAO       MOTIVO        EXPECTATIVAS AVAL_GERAL AVAL_BANHEIROS  \
# 0     melhorou  NR_NAO_SABE             superou          6              1
# 1     melhorou  NR_NAO_SABE         indiferente          9              1
# 2     melhorou  NR_NAO_SABE             superou          6              7
# 3  NR_NAO_SABE  NR_NAO_SABE  atendeu_plenamente          8              2
# 4     melhorou  NR_NAO_SABE             superou         10              1
#
#   AVAL_SEGURANCA AVAL_PRECOS PROXIMA_EDICAO MOTIVO_NAO BLOCOS_DE_RUA  \
# 0              3           5            sim        NaN           sim
# 1             10           1            sim        NaN           sim
# 2              5           6            sim        NaN           NaN
# 3              8           5            sim        NaN           NaN
# 4              9           7            sim        NaN           NaN
#
#   EVENTOS_PRIVADOS PALCOS CIRCUITO_GASTRONOMICO CITY_TOUR VISITA_CULTURAL  \
# 0              NaN    NaN                   NaN       NaN             NaN
# 1              NaN    NaN                   NaN       NaN             NaN
# 2              NaN    NaN                   NaN       NaN             NaN
# 3              NaN    NaN                   NaN       NaN             sim
# 4              NaN    NaN                   NaN       NaN             sim
#
#   NAO_SABE PRINCIPAL_PATROCINADOR     GENERO                 ESCOLARIDADE  \
# 0      NaN                 amstel  masculino     ensino_superior_completo
# 1      NaN            nr_nao_sabe   feminino        ensino_medio_completo
# 2      NaN                   skol   feminino        ensino_medio_completo
# 3      NaN                   skol   feminino  ensino_fundamental_completo
# 4      NaN             prefeitura   feminino     ensino_superior_completo
#
#   ESTADO_CIVIL                                 FAIXA_DE_RENDA  TRANSP_A_PE  \
# 0     solteiro    entre_1_sm_e_3_sm_(rs_998,01_a_rs_2.994,00)  outra_opcao
# 1     solteiro  entre_3_sm_e_5_sm_(rs_2.994,01_a_rs_4.990,00)  outra_opcao
# 2     solteiro                                    nr_nao_sabe  outra_opcao
# 3     solteiro                                    nr_nao_sabe  outra_opcao
# 4       casado  entre_3_sm_e_5_sm_(rs_2.994,01_a_rs_4.990,00)  outra_opcao
#
#                      TRANSP_APP TRANSP_BICICLETA TRANSP_CAR_AMIGOS_PARENTES  \
# 0                   outra_opcao      outra_opcao                outra_opcao
# 1                   outra_opcao      outra_opcao                outra_opcao
# 2  aplicativos_(uber_cabify_99)      outra_opcao                outra_opcao
# 3  aplicativos_(uber_cabify_99)      outra_opcao                outra_opcao
# 4  aplicativos_(uber_cabify_99)      outra_opcao                outra_opcao
#
#    TRANSP_TAXI TRANSP_OUTROS TRANSP_VEICULO_PROPRIO TRANSP_VEICULO_ALUGADO  \
# 0  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 1  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 2  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 3  outra_opcao   outra_opcao            outra_opcao            outra_opcao
# 4  outra_opcao   outra_opcao            outra_opcao            outra_opcao
#
#   TRANSP_ONIBUS_COLETIVO    TRANSP_NS TRANSP_METRO
# 0            outra_opcao  outra_opcao  outra_opcao
# 1            outra_opcao  outra_opcao  outra_opcao
# 2            outra_opcao  outra_opcao  outra_opcao
# 3            outra_opcao  outra_opcao  outra_opcao
# 4        onibus_coletivo  outra_opcao  outra_opcao

# %%
df['MORADOR'].value_counts()
# Out:
# MORADOR
# morador      961
# visitante    172
# Name: count, dtype: int64

# %%
df['BLOCO'].value_counts()
# Out:
# BLOCO
# entao_brilha              96
# baianas_ozadas            90
# chama_o_sindico           88
# bloco_havayanas_usadas    76
# quando_come_se_lambuza    66
# alo_abacaxi               65
# monobloco                 61
# bloco_angola_janga        55
# bloco_da_calixto          53
# funk_you                  51
# juventude_bronzeada       50
# garotas_solteiras         50
# ordinarios                50
# pena_de_pavao             48
# magnolia                  44
# sexta_ninguem_sabe        42
# bloco_volta_belchior      42
# tchanzinho_zona_norte     41
# beico_do_wando            34
# lindo_bloco_do_amor       31
# Name: count, dtype: int64

# %%
df['PAIS'].value_counts()
# Out:
# PAIS
# brasil            1129
# estados_unidos       2
# argentina            1
# irlanda              1
# Name: count, dtype: int64

# %%
df.corr(method='pearson', numeric_only=True)
#id e número de controle não agregam valor na análise
df = df.drop(columns=['id', 'número de controle'], errors='ignore')
df.corr(method='pearson', numeric_only=True)
# Out:
#                          ID  NUMERO_CONTROLE     IDADE  INDIVIDUAL_GASTOS
# ID                 1.000000         1.000000  0.098454          -0.126436
# NUMERO_CONTROLE    1.000000         1.000000  0.098454          -0.126436
# IDADE              0.098454         0.098454  1.000000           0.107356
# INDIVIDUAL_GASTOS -0.126436        -0.126436  0.107356           1.000000

# %%
df.corr(method='spearman', numeric_only=True)
# Out:
#                          ID  NUMERO_CONTROLE     IDADE  INDIVIDUAL_GASTOS
# ID                 1.000000         1.000000  0.093026          -0.033319
# NUMERO_CONTROLE    1.000000         1.000000  0.093026          -0.033319
# IDADE              0.093026         0.093026  1.000000           0.130951
# INDIVIDUAL_GASTOS -0.033319        -0.033319  0.130951           1.000000

# %%
print(f"Uso de memória ANTES da otimização (Real): {df.memory_usage(deep=True).sum() / 1024:.2f} KB")
print(f"Uso de memória ANTES da otimização (Padrão): {df.memory_usage(deep=False).sum() / 1024:.2f} KB")
print(df.columns.tolist())
df['MOTIVO_CARNAVAL'].value_counts()
# Out:
# Uso de memória ANTES da otimização (Real): 3884.88 KB
# Uso de memória ANTES da otimização (Padrão): 610.89 KB
# ['ID', 'MORADOR', 'NUMERO_CONTROLE', 'BLOCO', 'DT_VISITA', 'TEMPO_TOTAL_ENTREV', 'IDADE', 'PAIS', 'ESTADO', 'CIDADE', 'OUTRA_CIDADE', 'BAIRRO_BH', 'REGIAO_BH', 'REGIONAL_ORIGEM', 'PRETENDERIA_VIAJAR', 'PERNOITE_BH', 'T_PERNOITE', 'HOSPEDAGEM', 'TRANSPORTE', 'MOTIVO_CARNAVAL', 'MOTIVO_OUTRO', 'DIAS_CARNAVAL', 'GASTOS_PRETENDIDOS', 'PESSOAS_GASTOS', 'ALIMENTACAO_GASTOS', 'TRANSPORTE_GASTOS', 'FANTASIAS_GASTOS', 'COMPRAS_GASTOS', 'INGRESSOS_GASTOS', 'OUTROS_GASTOS', 'HOSPEDAGEM_GASTOS', 'PASSEIOS_GASTOS', 'TOTAL_GASTOS', 'INDIVIDUAL_GASTOS', 'DIARIO_GASTOS', 'FONTE_CARNAVAL', 'PARTICIPOU_ANOSANTERIORES', 'EVOLUCAO', 'MOTIVO', 'EXPECTATIVAS', 'AVAL_GERAL', 'AVAL_BANHEIROS', 'AVAL_SEGURANCA', 'AVAL_PRECOS', 'PROXIMA_EDICAO', 'MOTIVO_NAO', 'BLOCOS_DE_RUA', 'EVENTOS_PRIVADOS', 'PALCOS', 'CIRCUITO_GASTRONOMICO', 'CITY_TOUR', 'VISITA_CULTURAL', 'NAO_SABE', 'PRINCIPAL_PATROCINADOR', 'GENERO', 'ESCOLARIDADE', 'ESTADO_CIVIL', 'FAIXA_DE_RENDA', 'TRANSP_A_PE', 'TRANSP_APP', 'TRANSP_BICICLETA', 'TRANSP_CAR_AMIGOS_PARENTES', 'TRANSP_TAXI', 'TRANSP_OUTROS', 'TRANSP_VEICULO_PROPRIO', 'TRANSP_VEICULO_ALUGADO', 'TRANSP_ONIBUS_COLETIVO', 'TRANSP_NS', 'TRANSP_METRO']
# MOTIVO_CARNAVAL
# nr_nao_sabe    961
# sim            155
# nao             17
# Name: count, dtype: int64

# %%
df['GASTOS_PRETENDIDOS'].value_counts()
# Out:
# GASTOS_PRETENDIDOS
# 200            139
# 300            134
# 100            119
# 500            114
# 400             96
# 600             64
# 150             59
# 50              57
# 1000            48
# 250             45
# nr_nao_sabe     32
# 700             18
# 60              17
# 120             17
# 2000            16
# 30              15
# 80              15
# 800             14
# 1500            13
# 900              9
# 350              9
# 450              7
# 70               7
# 20               6
# 240              6
# 40               5
# 1200             5
# 4000             4
# 140              3
# 180              3
# 3000             3
# 550              2
# 220              2
# 360              2
# 25               2
# 160              2
# 420              2
# 2500             2
# 130              2
# 170              1
# 380              1
# 5000             1
# 90               1
# 650              1
# 1400             1
# 1700             1
# 1250             1
# 1300             1
# 3500             1
# 280              1
# 560              1
# 680              1
# 225              1
# 10000            1
# 210              1
# 750              1
# 15000            1
# Name: count, dtype: int64

# %%
# Converter colunas de texto para o tipo 'category'
for col in ['PAIS', 'MORADOR', 'BLOCO','PAIS', 'ESTADO', 'CIDADE', 'OUTRA_CIDADE', 'BAIRRO_BH', 'REGIAO_BH', 'REGIONAL_ORIGEM','MOTIVO', 'GENERO', 'ESCOLARIDADE', 'ESTADO_CIVIL','PRETENDERIA_VIAJAR', 'PERNOITE_BH','HOSPEDAGEM', 'TRANSPORTE','MOTIVO_CARNAVAL','MOTIVO_OUTRO','PESSOAS_GASTOS','FONTE_CARNAVAL','FONTE_CARNAVAL', 'PARTICIPOU_ANOSANTERIORES','EXPECTATIVAS', 'AVAL_GERAL', 'AVAL_BANHEIROS', 'AVAL_SEGURANCA', 'AVAL_PRECOS', 'PROXIMA_EDICAO', 'MOTIVO_NAO','BLOCOS_DE_RUA', 'EVENTOS_PRIVADOS', 'PALCOS', 'CIRCUITO_GASTRONOMICO', 'CITY_TOUR', 'VISITA_CULTURAL', 'NAO_SABE', 'PRINCIPAL_PATROCINADOR','FAIXA_DE_RENDA', 'TRANSP_A_PE', 'TRANSP_APP', 'TRANSP_BICICLETA', 'TRANSP_CAR_AMIGOS_PARENTES', 'TRANSP_TAXI', 'TRANSP_OUTROS', 'TRANSP_VEICULO_PROPRIO', 'TRANSP_VEICULO_ALUGADO', 'TRANSP_ONIBUS_COLETIVO', 'TRANSP_NS', 'TRANSP_METRO' ]:
    df[col] = df[col].astype('category')
#Converter coluna numérica para tipo inteiro
for col in ['T_PERNOITE', 'DIAS_CARNAVAL']:
    df[col] = df[col].replace('nr_nao_sabe', 0).fillna(0).astype(int)
#Converter colunas de gastos para tipo float (AQUI ACHO QUE TEVE PROBLEMA APARECERAM VALORES MUITO ALTOS)
for col in ['GASTOS_PRETENDIDOS','ALIMENTACAO_GASTOS', 'TRANSPORTE_GASTOS', 'FANTASIAS_GASTOS', 'COMPRAS_GASTOS', 'INGRESSOS_GASTOS', 'OUTROS_GASTOS', 'HOSPEDAGEM_GASTOS', 'PASSEIOS_GASTOS', 'TOTAL_GASTOS', 'INDIVIDUAL_GASTOS', 'DIARIO_GASTOS']:
    df[col] = df[col].replace('nr_nao_sabe', 0)
    # Remove todos os pontos e espaços, depois troca vírgula por ponto
    df[col] = df[col].astype(str).str.replace('.', '', regex=False).str.replace(',', '.', regex=False).str.replace(' ', '')
    # Se ainda houver valores não numéricos, substitui por 0
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(float)
#Converter coluna de data para tipo datetime
df['DT_VISITA'] = pd.to_datetime(df['DT_VISITA'], errors='coerce')
#Converter coluna de duração para tipo timedelta
df['TEMPO_TOTAL_ENTREV'] = pd.to_timedelta(df['TEMPO_TOTAL_ENTREV'], errors='coerce')
print(f"Uso de memória DEPOIS  (Real): {df.memory_usage(deep=True).sum() / 1024:.2f} KB")
print(f"Uso de memória DEPOIS  (Padrão): {df.memory_usage(deep=False).sum() / 1024:.2f} KB")
# Out:
# Uso de memória DEPOIS  (Real): 340.41 KB
# Uso de memória DEPOIS  (Padrão): 253.76 KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1133 non-null   int64
#  1   MORADOR                     1133 non-null   category
#  2   NUMERO_CONTROLE             1133 non-null   int64
#  3   BLOCO                       1133 non-null   category
#  4   DT_VISITA                   1132 non-null   datetime64[ns]
#  5   TEMPO_TOTAL_ENTREV          1126 non-null   timedelta64[ns]
#  6   IDADE                       1133 non-null   int64
#  7   PAIS                        1133 non-null   category
#  8   ESTADO                      1133 non-null   category
#  9   CIDADE                      1133 non-null   category
#  10  OUTRA_CIDADE                172 non-null    category
#  11  BAIRRO_BH                   757 non-null    category
#  12  REGIAO_BH                   757 non-null    category
#  13  REGIONAL_ORIGEM             1133 non-null   category
#  14  PRETENDERIA_VIAJAR          1133 non-null   category
#  15  PERNOITE_BH                 1133 non-null   category
#  16  T_PERNOITE                  1133 non-null   int64
#  17  HOSPEDAGEM                  1133 non-null   category
#  18  TRANSPORTE                  1133 non-null   category
#  19  MOTIVO_CARNAVAL             1133 non-null   category
#  20  MOTIVO_OUTRO                1133 non-null   category
#  21  DIAS_CARNAVAL               1133 non-null   int64
#  22  GASTOS_PRETENDIDOS          1133 non-null   float64
#  23  PESSOAS_GASTOS              1133 non-null   category
#  24  ALIMENTACAO_GASTOS          1133 non-null   float64
#  25  TRANSPORTE_GASTOS           1133 non-null   float64
#  26  FANTASIAS_GASTOS            1133 non-null   float64
#  27  COMPRAS_GASTOS              1133 non-null   float64
#  28  INGRESSOS_GASTOS            1133 non-null   float64
#  29  OUTROS_GASTOS               1133 non-null   float64
#  30  HOSPEDAGEM_GASTOS           1133 non-null   float64
#  31  PASSEIOS_GASTOS             1133 non-null   float64
#  32  TOTAL_GASTOS                1133 non-null   float64
#  33  INDIVIDUAL_GASTOS           1133 non-null   float64
#  34  DIARIO_GASTOS               1133 non-null   float64
#  35  FONTE_CARNAVAL              1133 non-null   category
#  36  PARTICIPOU_ANOSANTERIORES   1133 non-null   category
#  37  EVOLUCAO                    1133 non-null   object
#  38  MOTIVO                      1133 non-null   category
#  39  EXPECTATIVAS                1133 non-null   category
#  40  AVAL_GERAL                  1133 non-null   category
#  41  AVAL_BANHEIROS              1133 non-null   category
#  42  AVAL_SEGURANCA              1133 non-null   category
#  43  AVAL_PRECOS                 1133 non-null   category
#  44  PROXIMA_EDICAO              1133 non-null   category
#  45  MOTIVO_NAO                  45 non-null     category
#  46  BLOCOS_DE_RUA               134 non-null    category
#  47  EVENTOS_PRIVADOS            132 non-null    category
#  48  PALCOS                      180 non-null    category
#  49  CIRCUITO_GASTRONOMICO       4 non-null      category
#  50  CITY_TOUR                   6 non-null      category
#  51  VISITA_CULTURAL             13 non-null     category
#  52  NAO_SABE                    55 non-null     category
#  53  PRINCIPAL_PATROCINADOR      1133 non-null   category
#  54  GENERO                      1133 non-null   category
#  55  ESCOLARIDADE                1133 non-null   category
#  56  ESTADO_CIVIL                1133 non-null   category
#  57  FAIXA_DE_RENDA              1133 non-null   category
#  58  TRANSP_A_PE                 1133 non-null   category
#  59  TRANSP_APP                  1133 non-null   category
#  60  TRANSP_BICICLETA            1133 non-null   category
#  61  TRANSP_CAR_AMIGOS_PARENTES  1133 non-null   category
#  62  TRANSP_TAXI                 1133 non-null   category
#  63  TRANSP_OUTROS               1133 non-null   category
#  64  TRANSP_VEICULO_PROPRIO      1133 non-null   category
#  65  TRANSP_VEICULO_ALUGADO      1133 non-null   category
#  66  TRANSP_ONIBUS_COLETIVO      1133 non-null   category
#  67  TRANSP_NS                   1133 non-null   category
#  68  TRANSP_METRO                1133 non-null   category
# dtypes: category(49), datetime64[ns](1), float64(12), int64(5), object(1), timedelta64[ns](1)
# memory usage: 340.4 KB

# %%
df.describe(include='all').T
df.describe().T
# Out:
#                      count                           mean  \
# ID                  1133.0                          567.0
# NUMERO_CONTROLE     1133.0                          567.0
# DT_VISITA             1132  2019-03-08 05:45:56.554770432
# TEMPO_TOTAL_ENTREV    1126      0 days 00:04:46.498223801
# IDADE               1133.0                       32.31068
# T_PERNOITE          1133.0                       0.673433
# DIAS_CARNAVAL       1133.0                       3.891439
# GASTOS_PRETENDIDOS  1133.0                     410.542807
# ALIMENTACAO_GASTOS  1133.0                       1.543689
# TRANSPORTE_GASTOS   1133.0                     233.773169
# FANTASIAS_GASTOS    1133.0                      77.917034
# COMPRAS_GASTOS      1133.0                      43.747573
# INGRESSOS_GASTOS    1133.0                      28.030891
# OUTROS_GASTOS       1133.0                      15.551633
# HOSPEDAGEM_GASTOS   1133.0                       4.553398
# PASSEIOS_GASTOS     1133.0                      23.124448
# TOTAL_GASTOS        1133.0                       1.001765
# INDIVIDUAL_GASTOS   1133.0                     423.455428
# DIARIO_GASTOS       1133.0                      346.67105
#
#                                     min                     25%  \
# ID                                  1.0                   284.0
# NUMERO_CONTROLE                     1.0                   284.0
# DT_VISITA           2019-01-03 16:16:00     2019-02-03 11:00:45
# TEMPO_TOTAL_ENTREV      0 days 00:01:34  0 days 00:03:40.250000
# IDADE                              16.0                    24.0
# T_PERNOITE                          0.0                     0.0
# DIAS_CARNAVAL                       0.0                     3.0
# GASTOS_PRETENDIDOS                  0.0                   120.0
# ALIMENTACAO_GASTOS                  0.0                     1.0
# TRANSPORTE_GASTOS                   0.0                    60.0
# FANTASIAS_GASTOS                    0.0                    20.0
# COMPRAS_GASTOS                      0.0                     0.0
# INGRESSOS_GASTOS                    0.0                     0.0
# OUTROS_GASTOS                       0.0                     0.0
# HOSPEDAGEM_GASTOS                   0.0                     0.0
# PASSEIOS_GASTOS                     0.0                     0.0
# TOTAL_GASTOS                        0.0                     0.0
# INDIVIDUAL_GASTOS                   0.0                   140.0
# DIARIO_GASTOS                       0.0                   100.0
#
#                                        50%                  75%  \
# ID                                   567.0                850.0
# NUMERO_CONTROLE                      567.0                850.0
# DT_VISITA              2019-03-03 10:38:00  2019-04-03 12:30:45
# TEMPO_TOTAL_ENTREV  0 days 00:04:24.500000      0 days 00:05:28
# IDADE                                 29.0                 39.0
# T_PERNOITE                             0.0                  0.0
# DIAS_CARNAVAL                          4.0                  5.0
# GASTOS_PRETENDIDOS                   300.0                500.0
# ALIMENTACAO_GASTOS                     1.0                  2.0
# TRANSPORTE_GASTOS                    150.0                300.0
# FANTASIAS_GASTOS                      50.0                100.0
# COMPRAS_GASTOS                         0.0                 50.0
# INGRESSOS_GASTOS                       0.0                  0.0
# OUTROS_GASTOS                          0.0                  0.0
# HOSPEDAGEM_GASTOS                      0.0                  0.0
# PASSEIOS_GASTOS                        0.0                  0.0
# TOTAL_GASTOS                           0.0                  0.0
# INDIVIDUAL_GASTOS                    290.0                500.0
# DIARIO_GASTOS                        215.0                400.0
#
#                                     max                        std
# ID                               1133.0                 327.213233
# NUMERO_CONTROLE                  1133.0                 327.213233
# DT_VISITA           2019-05-03 13:47:00                        NaN
# TEMPO_TOTAL_ENTREV      0 days 00:30:21  0 days 00:02:00.300606801
# IDADE                              73.0                   11.55478
# T_PERNOITE                         21.0                   1.835835
# DIAS_CARNAVAL                       6.0                   1.490739
# GASTOS_PRETENDIDOS              15000.0                 699.192139
# ALIMENTACAO_GASTOS                 15.0                   1.224416
# TRANSPORTE_GASTOS                3200.0                 303.973396
# FANTASIAS_GASTOS                 1000.0                  89.224091
# COMPRAS_GASTOS                   1000.0                   89.41086
# INGRESSOS_GASTOS                 2700.0                 140.743985
# OUTROS_GASTOS                    1000.0                  65.077246
# HOSPEDAGEM_GASTOS                 800.0                  40.980583
# PASSEIOS_GASTOS                  2500.0                 144.953811
# TOTAL_GASTOS                     1000.0                  29.788536
# INDIVIDUAL_GASTOS                5450.0                  534.95736
# DIARIO_GASTOS                    5145.0                 479.129162

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
#histograma da idade
sns.histplot(df['IDADE'], bins=30, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribuição de Idade')
axes[0, 0].set_xlabel('Idade')
axes[0, 0].set_ylabel('Frequência')
#histograma da dias de carnaval
sns.histplot(df['DIAS_CARNAVAL'], bins=10, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Distribuição de Dias de Carnaval')  
axes[0, 1].set_xlabel('Dias de Carnaval')
axes[0, 1].set_ylabel('Frequência') 
#filtrar gastos 
df_gastos_filtrados = df[(df['GASTOS_PRETENDIDOS'] > 0) & (df['TOTAL_GASTOS'] > 0)]
#histograma dos gastos pretendidos
sns.histplot(df_gastos_filtrados['GASTOS_PRETENDIDOS'], bins=10, kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Distribuição de Gastos Pretendidos')
axes[1, 0].set_xlabel('Gastos Pretendidos (R$)')
axes[1, 0].set_ylabel('Frequência') 

#histograma dos gastos totais removendo 0
sns.histplot(df_gastos_filtrados['TOTAL_GASTOS'], bins=10, kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Distribuição de Gastos Totais')    
axes[1, 1].set_xlabel('Gastos Totais (R$)')
axes[1, 1].set_ylabel('Frequência')
plt.tight_layout()
plt.show()
